# %%
#Librerias implementadas
import scipy.io
import copy
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import time
import pickle
import scipy.io as sio
from sklearn import svm
from sklearn import linear_model
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import tree
from sklearn.cluster import KMeans
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix, precision_score, f1_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import recall_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import median_absolute_error
from sklearn.metrics import mean_squared_error
from IPython.display import Image
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV 
from sklearn.model_selection import KFold

# %%
#....
def cargardatos(datos_tesis):

    datos=pd.read_csv(datos_tesis, sep=',')
    datos=datos.drop(['LOGICA COMPUTACIONAL','PROGRAMACION I','PROGRAMACION II','PROGRAMACION III'], axis=1)
    

    X = datos[['LECTURA CRITICA','MATEMATICA','INGLES','SOCIALES Y CIUDADANIA','CIENCIAS NATURALES']]
    Y = datos['PROMEDIO PROGRAMACIONES']
    X = X.to_numpy()
    Y = Y.to_numpy()
    return(X,Y)

# %%
X,Y=cargardatos('Datos-Tesis.csv')

# %%
#MODELO DE SUPPORT VECTOR REGRESSION


#Definir la cantidad de datos que se asignarán al conjunto de entrenamiento y de prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
#print(X_train, X_test, y_train, y_test)
#Definir elementos para evaluación de los modelos

kf = KFold(n_splits=5)

sv =SVR(C=1.0, epsilon=0.5)

#sv.fit(X_train, y_train)

#scores = cross_val_score(sv, X_train, y_train, cv=kf, scoring="r2")
#print("Metricas cross_validation", scores)

# %%
# define grid
grid1 = dict()
grid1['kernel'] = ['linear', 'poly', 'rbf', 'sigmoid']
grid1['degree'] = [2,3,4,5,6,7]
sco=['neg_mean_squared_error','neg_median_absolute_error','r2']

# define search

search1 = GridSearchCV(sv, grid1, scoring='r2', cv=kf, n_jobs=-1)
# perform the search
results = search1.fit(X_train, Y_train)
pos=(-1)* results.best_score_
# summarize best
print('Best  r2: %.3f' % pos)
print('Best Config: %s' % results.best_params_)
# summarize all
means = results.cv_results_['mean_test_score']
params = results.cv_results_['params']
for mean, param in zip(means, params):
    print(">%.3f with: %r" % (mean * -1, param))
# Out:
# Best  r2: 0.647
# Best Config: {'degree': 2, 'kernel': 'rbf'}
# >1.636 with: {'degree': 2, 'kernel': 'linear'}
# >1.417 with: {'degree': 2, 'kernel': 'poly'}
# >0.647 with: {'degree': 2, 'kernel': 'rbf'}
# >0.892 with: {'degree': 2, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 3, 'kernel': 'linear'}
# >1.368 with: {'degree': 3, 'kernel': 'poly'}
# >0.647 with: {'degree': 3, 'kernel': 'rbf'}
# >0.892 with: {'degree': 3, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 4, 'kernel': 'linear'}
# >1.423 with: {'degree': 4, 'kernel': 'poly'}
# >0.647 with: {'degree': 4, 'kernel': 'rbf'}
# >0.892 with: {'degree': 4, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 5, 'kernel': 'linear'}
# >1.549 with: {'degree': 5, 'kernel': 'poly'}
# >0.647 with: {'degree': 5, 'kernel': 'rbf'}
# >0.892 with: {'degree': 5, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 6, 'kernel': 'linear'}
# >1.637 with: {'degree': 6, 'kernel': 'poly'}
# >0.647 with: {'degree': 6, 'kernel': 'rbf'}
# >0.892 with: {'degree': 6, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 7, 'kernel': 'linear'}
# >1.624 with: {'degree': 7, 'kernel': 'poly'}
# >0.647 with: {'degree': 7, 'kernel': 'rbf'}
# >0.892 with: {'degree': 7, 'kernel': 'sigmoid'}

# %%
# define grid
grid1 = dict()
grid1['kernel'] = ['linear', 'poly', 'rbf', 'sigmoid']
grid1['degree'] = [2,3,4,5,6,7]
sco=['neg_mean_squared_error','neg_median_absolute_error','r2']

# define search

search1 = GridSearchCV(sv, grid1, scoring='neg_mean_squared_error', cv=kf, n_jobs=-1)
# perform the search
results = search1.fit(X_train, Y_train)
pos=(-1)* results.best_score_
# summarize best
print('Best  neg_mean_squared_error: %.3f' % pos)
print('Best Config: %s' % results.best_params_)
# summarize all
means = results.cv_results_['mean_test_score']
params = results.cv_results_['params']
for mean, param in zip(means, params):
    print(">%.3f with: %r" % (mean * -1, param))
# Out:
# Best  neg_mean_squared_error: 0.086
# Best Config: {'degree': 2, 'kernel': 'rbf'}
# >0.121 with: {'degree': 2, 'kernel': 'linear'}
# >0.118 with: {'degree': 2, 'kernel': 'poly'}
# >0.086 with: {'degree': 2, 'kernel': 'rbf'}
# >0.096 with: {'degree': 2, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 3, 'kernel': 'linear'}
# >0.118 with: {'degree': 3, 'kernel': 'poly'}
# >0.086 with: {'degree': 3, 'kernel': 'rbf'}
# >0.096 with: {'degree': 3, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 4, 'kernel': 'linear'}
# >0.122 with: {'degree': 4, 'kernel': 'poly'}
# >0.086 with: {'degree': 4, 'kernel': 'rbf'}
# >0.096 with: {'degree': 4, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 5, 'kernel': 'linear'}
# >0.129 with: {'degree': 5, 'kernel': 'poly'}
# >0.086 with: {'degree': 5, 'kernel': 'rbf'}
# >0.096 with: {'degree': 5, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 6, 'kernel': 'linear'}
# >0.136 with: {'degree': 6, 'kernel': 'poly'}
# >0.086 with: {'degree': 6, 'kernel': 'rbf'}
# >0.096 with: {'degree': 6, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 7, 'kernel': 'linear'}
# >0.137 with: {'degree': 7, 'kernel': 'poly'}
# >0.086 with: {'degree': 7, 'kernel': 'rbf'}
# >0.096 with: {'degree': 7, 'kernel': 'sigmoid'}

# %%
# define grid
grid1 = dict()
grid1['kernel'] = ['linear', 'poly', 'rbf', 'sigmoid']
grid1['degree'] = [2,3,4,5,6,7]
sco=['neg_mean_squared_error','neg_median_absolute_error','r2']

# define search

search1 = GridSearchCV(sv, grid1, scoring='neg_root_mean_squared_error', cv=kf, n_jobs=-1)
# perform the search
results = search1.fit(X_train, Y_train)
pos=(-1)* results.best_score_
# summarize best
print('Best   neg_root_mean_squared_error: %.3f' % pos)
print('Best Config: %s' % results.best_params_)
# summarize all
means = results.cv_results_['mean_test_score']
params = results.cv_results_['params']
for mean, param in zip(means, params):
    print(">%.3f with: %r" % (mean * -1, param))
# Out:
# Best   neg_root_mean_squared_error: 0.280
# Best Config: {'degree': 2, 'kernel': 'rbf'}
# >0.342 with: {'degree': 2, 'kernel': 'linear'}
# >0.337 with: {'degree': 2, 'kernel': 'poly'}
# >0.280 with: {'degree': 2, 'kernel': 'rbf'}
# >0.299 with: {'degree': 2, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 3, 'kernel': 'linear'}
# >0.335 with: {'degree': 3, 'kernel': 'poly'}
# >0.280 with: {'degree': 3, 'kernel': 'rbf'}
# >0.299 with: {'degree': 3, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 4, 'kernel': 'linear'}
# >0.340 with: {'degree': 4, 'kernel': 'poly'}
# >0.280 with: {'degree': 4, 'kernel': 'rbf'}
# >0.299 with: {'degree': 4, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 5, 'kernel': 'linear'}
# >0.348 with: {'degree': 5, 'kernel': 'poly'}
# >0.280 with: {'degree': 5, 'kernel': 'rbf'}
# >0.299 with: {'degree': 5, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 6, 'kernel': 'linear'}
# >0.355 with: {'degree': 6, 'kernel': 'poly'}
# >0.280 with: {'degree': 6, 'kernel': 'rbf'}
# >0.299 with: {'degree': 6, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 7, 'kernel': 'linear'}
# >0.354 with: {'degree': 7, 'kernel': 'poly'}
# >0.280 with: {'degree': 7, 'kernel': 'rbf'}
# >0.299 with: {'degree': 7, 'kernel': 'sigmoid'}

# %%
# define grid
grid1 = dict()
grid1['kernel'] = ['linear', 'poly', 'rbf', 'sigmoid']
grid1['degree'] = [2,3,4,5,6,7]
#gamma solo es aplicable a los kernels de rbf,poly,sigmoid (o de tipo scale, use / n_features)
grid1['gamma']  = ['scale', 'auto', 0.1, 0.1] 
sco=['neg_mean_squared_error','neg_median_absolute_error','r2']
#modificar numeros de gamma para las pruebas
# define search

search1 = GridSearchCV(sv, grid1, scoring='r2', cv=kf, n_jobs=-1)
# perform the search
results = search1.fit(X_train, Y_train)
pos=(-1)* results.best_score_
# summarize best
print('Best  r2: %.3f' % pos)
print('Best Config: %s' % results.best_params_)
# summarize all
means = results.cv_results_['mean_test_score']
params = results.cv_results_['params']
for mean, param in zip(means, params):
    print(">%.3f with: %r" % (mean * -1, param))
# Out:
# Best  r2: 0.504
# Best Config: {'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# >1.636 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# >1.417 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# >1.417 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# >1.417 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# >1.417 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# >1.368 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# >1.369 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# >1.369 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# >1.369 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'linear'}
# >1.423 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'linear'}
# >1.424 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# >1.424 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# >1.424 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# >1.549 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# >1.549 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# >1.549 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# >1.549 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'linear'}
# >1.637 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'linear'}
# >1.637 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'linear'}
# >1.637 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'linear'}
# >1.637 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# >1.624 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# >1.625 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'linear'}
# >1.625 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >1.636 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'linear'}
# >1.625 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'poly'}
# >0.504 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.892 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'sigmoid'}

# %%
# define grid
grid1 = dict()
grid1['kernel'] = ['linear', 'poly', 'rbf', 'sigmoid']
grid1['degree'] = [2,3,4,5,6,7]
#gamma solo es aplicable a los kernels de rbf,poly,sigmoid (o de tipo scale, use / n_features)
grid1['gamma']  = ['scale', 'auto', 0.1, 0.1] 
sco=['neg_mean_squared_error','neg_median_absolute_error','r2']
#modificar numeros de gamma para las pruebas
# define search

search1 = GridSearchCV(sv, grid1, scoring='neg_mean_squared_error', cv=kf, n_jobs=-1)
# perform the search
results = search1.fit(X_train, Y_train)
pos=(-1)* results.best_score_
# summarize best
print('Best  neg_mean_squared_error: %.3f' % pos)
print('Best Config: %s' % results.best_params_)
# summarize all
means = results.cv_results_['mean_test_score']
params = results.cv_results_['params']
for mean, param in zip(means, params):
    print(">%.3f with: %r" % (mean * -1, param))
# Out:
# Best  neg_mean_squared_error: 0.084
# Best Config: {'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.121 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# >0.118 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# >0.086 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.096 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# >0.118 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# >0.084 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.096 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# >0.118 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# >0.118 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# >0.118 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# >0.086 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.096 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# >0.119 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# >0.084 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.096 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# >0.119 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# >0.119 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'linear'}
# >0.122 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# >0.086 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.096 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'linear'}
# >0.122 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# >0.084 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.096 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# >0.122 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# >0.122 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# >0.129 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# >0.086 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.096 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# >0.129 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# >0.084 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.096 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# >0.129 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# >0.129 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'linear'}
# >0.136 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# >0.086 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.096 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'linear'}
# >0.136 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# >0.084 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.096 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'linear'}
# >0.136 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'linear'}
# >0.136 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# >0.137 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# >0.086 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.096 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# >0.137 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# >0.084 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.096 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'linear'}
# >0.137 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.121 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'linear'}
# >0.137 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'poly'}
# >0.084 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.096 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'sigmoid'}

# %%
# define grid
grid1 = dict()
grid1['kernel'] = ['linear', 'poly', 'rbf', 'sigmoid']
grid1['degree'] = [2,3,4,5,6,7]
#gamma solo es aplicable a los kernels de rbf,poly,sigmoid (o de tipo scale, use / n_features)
grid1['gamma']  = ['scale', 'auto', 0.1, 0.1] 
sco=['neg_mean_squared_error','neg_median_absolute_error','r2']
#modificar numeros de gamma para las pruebas
# define search

search1 = GridSearchCV(sv, grid1, scoring='neg_root_mean_squared_error', cv=kf, n_jobs=-1)
# perform the search
results = search1.fit(X_train, Y_train)
pos=(-1)* results.best_score_
# summarize best
print('Best  neg_root_mean_squared_error: %.3f' % pos)
print('Best Config: %s' % results.best_params_)
# summarize all
means = results.cv_results_['mean_test_score']
params = results.cv_results_['params']
for mean, param in zip(means, params):
    print(">%.3f with: %r" % (mean * -1, param))
# Out:
# Best  neg_root_mean_squared_error: 0.276
# Best Config: {'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.342 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# >0.337 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# >0.280 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.299 with: {'degree': 2, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# >0.337 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# >0.276 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.299 with: {'degree': 2, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# >0.337 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# >0.337 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# >0.335 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# >0.280 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.299 with: {'degree': 3, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# >0.335 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# >0.276 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.299 with: {'degree': 3, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# >0.335 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# >0.335 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'linear'}
# >0.340 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# >0.280 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.299 with: {'degree': 4, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'linear'}
# >0.340 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# >0.276 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.299 with: {'degree': 4, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# >0.340 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# >0.340 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# >0.348 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# >0.280 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.299 with: {'degree': 5, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# >0.348 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# >0.276 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.299 with: {'degree': 5, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# >0.348 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# >0.348 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'linear'}
# >0.355 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# >0.280 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.299 with: {'degree': 6, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'linear'}
# >0.355 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# >0.276 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.299 with: {'degree': 6, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'linear'}
# >0.355 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'linear'}
# >0.355 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 6, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# >0.354 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# >0.280 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.299 with: {'degree': 7, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# >0.354 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# >0.276 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.299 with: {'degree': 7, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'linear'}
# >0.354 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'sigmoid'}
# >0.342 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'linear'}
# >0.354 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'poly'}
# >0.276 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'rbf'}
# >0.299 with: {'degree': 7, 'gamma': 0.1, 'kernel': 'sigmoid'}

# %%
# define grid
grid1 = dict()
grid1['kernel'] = ['linear', 'poly', 'rbf', 'sigmoid']
grid1['degree'] = [2,3,4,5,6,7]

#gamma solo es aplicable a los kernels de rbf,poly,sigmoid (o de tipo scale, use / n_features)
grid1['gamma']  = ['scale', 'auto', 0.2, 0.2] 
#coeficiente solo funciona para poly y sigmoid
grid1['coef0'] = [7]
sco=['neg_mean_squared_error','neg_median_absolute_error','r2']
#modificar numeros de gamma para las pruebas
# define search

search1 = GridSearchCV(sv, grid1, scoring='r2', cv=kf, n_jobs=-1)
# perform the search
results = search1.fit(X_train, Y_train)
pos=(-1)* results.best_score_
# summarize best
print('Best  r2: %.3f' % pos)
print('Best Config: %s' % results.best_params_)
# summarize all
means = results.cv_results_['mean_test_score']
params = results.cv_results_['params']
for mean, param in zip(means, params):
    print(">%.3f with: %r" % (mean * -1, param))
# Out:
# Best  r2: 0.505
# Best Config: {'coef0': 7, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# >1.636 with: {'coef0': 7, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# >1.434 with: {'coef0': 7, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'coef0': 7, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 2, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# >1.417 with: {'coef0': 7, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 2, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 2, 'gamma': 0.2, 'kernel': 'linear'}
# >1.417 with: {'coef0': 7, 'degree': 2, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 2, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 2, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 2, 'gamma': 0.2, 'kernel': 'linear'}
# >1.417 with: {'coef0': 7, 'degree': 2, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 2, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 2, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# >1.394 with: {'coef0': 7, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'coef0': 7, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 3, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# >1.368 with: {'coef0': 7, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 3, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 3, 'gamma': 0.2, 'kernel': 'linear'}
# >1.368 with: {'coef0': 7, 'degree': 3, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 3, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 3, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 3, 'gamma': 0.2, 'kernel': 'linear'}
# >1.368 with: {'coef0': 7, 'degree': 3, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 3, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 3, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 4, 'gamma': 'scale', 'kernel': 'linear'}
# >1.419 with: {'coef0': 7, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'coef0': 7, 'degree': 4, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 4, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 4, 'gamma': 'auto', 'kernel': 'linear'}
# >1.423 with: {'coef0': 7, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 4, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 4, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 4, 'gamma': 0.2, 'kernel': 'linear'}
# >1.423 with: {'coef0': 7, 'degree': 4, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 4, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 4, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 4, 'gamma': 0.2, 'kernel': 'linear'}
# >1.423 with: {'coef0': 7, 'degree': 4, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 4, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 4, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# >1.480 with: {'coef0': 7, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'coef0': 7, 'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 5, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# >1.547 with: {'coef0': 7, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 5, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 5, 'gamma': 0.2, 'kernel': 'linear'}
# >1.547 with: {'coef0': 7, 'degree': 5, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 5, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 5, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 5, 'gamma': 0.2, 'kernel': 'linear'}
# >1.547 with: {'coef0': 7, 'degree': 5, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 5, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 5, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 6, 'gamma': 'scale', 'kernel': 'linear'}
# >1.596 with: {'coef0': 7, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'coef0': 7, 'degree': 6, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 6, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 6, 'gamma': 'auto', 'kernel': 'linear'}
# >1.639 with: {'coef0': 7, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 6, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 6, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 6, 'gamma': 0.2, 'kernel': 'linear'}
# >1.639 with: {'coef0': 7, 'degree': 6, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 6, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 6, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 6, 'gamma': 0.2, 'kernel': 'linear'}
# >1.639 with: {'coef0': 7, 'degree': 6, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 6, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 6, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# >1.683 with: {'coef0': 7, 'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# >0.647 with: {'coef0': 7, 'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 7, 'gamma': 'scale', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# >1.628 with: {'coef0': 7, 'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 7, 'gamma': 'auto', 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 7, 'gamma': 0.2, 'kernel': 'linear'}
# >1.628 with: {'coef0': 7, 'degree': 7, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 7, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 7, 'gamma': 0.2, 'kernel': 'sigmoid'}
# >1.636 with: {'coef0': 7, 'degree': 7, 'gamma': 0.2, 'kernel': 'linear'}
# >1.628 with: {'coef0': 7, 'degree': 7, 'gamma': 0.2, 'kernel': 'poly'}
# >0.505 with: {'coef0': 7, 'degree': 7, 'gamma': 0.2, 'kernel': 'rbf'}
# >0.892 with: {'coef0': 7, 'degree': 7, 'gamma': 0.2, 'kernel': 'sigmoid'}
